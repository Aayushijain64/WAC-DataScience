# %%
a =2.6
b=10.5

# %%
print(a)
# Out:
# 2.6

# %% [markdown]
# ## Operators

# %%
print(a+b,end = ",")
print(a-b)
# Out:
# 13.1,-7.9

# %%
print(a-b)
# Out:
# -7.9

# %%
print(a*b)
# Out:
# 27.3

# %%
print(b/a)
# Out:
# 4.038461538461538

# %%
print(a**b)
# Out:
# 22762.510214724673

# %%
print(b%a)
# Out:
# 0.09999999999999964

# %%
print(int(b//a))
# Out:
# 4

# %% [markdown]
# ### Typecasting

# %%
num1 = float(input())
num2 = float(input())
print(num1+num2)
# Out:
# 12
# 65
# 77.0

# %%
print("Hello \nWorld")
# Out:
# Hello
# World

# %% [markdown]
# ### Lists -> arrays(C++)

# %%
list1 = [1,2,3,4,5,6]
list2 = [2,4,6,8,10]

# %%
records = [['Aayushi',24],['Sampat',45],['Kapil',76]]
print(records)
# Out:
# [['Aayushi', 24], ['Sampat', 45], ['Kapil', 76]]

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(list1)
print(list1+list2) #it wont give the sum of both
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 2, 4, 6, 8, 10]

# %%
print(list1[2])
# Out:
# 3

# %%
print(list1[:3])
# Out:
# [1, 2, 3]

# %%
pos = int(input())
num = int(input())
list1[pos] = num
print(list1)
# Out:
# 4
# 23
# [1, 2, 10, 4, 23, 6]

# %% [markdown]
# ### Dictionaries

# %%
records = {'Aayushi' : 32 , 'Sampat' : 45, 'Rishabh' : 87}
print(records)
# Out:
# {'Aayushi': 32, 'Sampat': 45, 'Rishabh': 87}

# %%
for keys in records.values():
    print(keys)
# Out:
# 32
# 45
# 87

# %%
print(int((records['Aayushi'])))
# Out:
# 32

# %% [markdown]
# ### Tuples

# %%
list1 = ['Aayushi',0,56]
list1[0] = "kapil"
print(list1)
# Out:
# ['kapil', 0, 56]

# %%
tuple1 = ('Aayushi',0,56)
tuple1[0] = "Kapil"
print(tuple1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-ddbec1ea2952> in <module>
#       1 tuple1 = ('Aayushi',0,56)
# ----> 2 tuple1[0] = "Kapil"
#       3 print(tuple1)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Sets

# %%
for i in range(0,10,2):
    print(i,end=" ")
print("")
print(i)
# Out:
# 0 2 4 6 8
# 8

# %%
string1 = "apple"
print(string1)
length = len(string1)
# Out:
# apple

# %%
for i in range(0,length):
    print(string1[i],end=" ")
# Out:
# a p p l e

# %%
for i in string1:
    print(i,end=" ")
# Out:
# a p p l e

# %%
list1 = [1,2,3,4]
length = len(list1)
print(sum(list1))
print(max(list1))
print(length)
# Out:
# 10
# 4
# 4

# %%
# Out:
# 88
# 88

# %%
number1 = int(input())
if number1%2==0:
    print("even")
else:
    print("odd")
# Out:
# 23
# odd

# %%
number2 =int(input())
if number2%2==0 :
    print("divisible by 2")
elif number2%5== 0 :
    print("divisible by 5")
else:
    print("not divisible by both")
# Out:
# 34
# divisible by 2

# %%
string2 = "apple"
length = len(string2)
i=0
while(i<length):
    print(string1[i],end=" ")
    i +=1
# Out:
# a p p l e

# %%
def sum1(a,b):
    d=a+b
    return d
d= sum1(34,54)

print (d)
# Out:
# 88
